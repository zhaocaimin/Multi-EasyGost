# %% [markdown]
# <a href="https://colab.research.google.com/github/zhaocaimin/Multi-EasyGost/blob/master/novel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 基於 4chan 魔改版 NovelAILeaks (naifu) 製作。 [來源](https://boards.4channel.org/g/thread/89095460#p89097704)
#
# 使用官方前端 + 優化版後端，可突破75限制，支持所有模型。

# %%
#@title ### 0. 檢查 GPU 工作狀態

# !nvidia-smi
# Out:
# Thu Oct 27 14:48:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@title ### 1. 下載 Novel AI API 後端、模型 
#@markdown 如果下載速度太慢可以嘗試 restart

# %cd /content/
# !apt install -y -qq aria2
# !aria2c --summary-interval=5 -x 3 --allow-overwrite=true -Z \
  https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/naifu.tar \
  https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/animefull-latest.tar 
  
# !echo "Decompressing..."
# !tar xf naifu.tar && rm naifu.tar
# !echo "Done."
# Out:
# /content
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libc-ares2
# The following NEW packages will be installed:
#   aria2 libc-ares2
# 0 upgraded, 2 newly installed, 0 to remove and 27 not upgraded.
# Need to get 1,274 kB of archives.
# After this operation, 4,912 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 123942 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.14.0-1ubuntu0.1_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.14.0-1ubuntu0.1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.33.1-1_amd64.deb ...
# Unpacking aria2 (1.33.1-1) ...
# Setting up libc-ares2:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up aria2 (1.33.1-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
#
# 10/27 14:48:55 [NOTICE] Downloading 2 item(s)
#  *** Download Progress Summary as of Thu Oct 27 14:49:01 2022 ***
# =
# [#9c9d46 642MiB/7.4GiB(8%) CN:3 DL:111MiB ETA:1m2s]
# FILE: /content/naifu.tar
# -
# [#8b1179 606MiB/7.1GiB(8%) CN:3 DL:105MiB ETA:1m4s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:07 2022 ***
# =
# [#9c9d46 1.2GiB/7.4GiB(17%) CN:3 DL:113MiB ETA:55s]
# FILE: /content/naifu.tar
# -
# [#8b1179 1.2GiB/7.1GiB(17%) CN:3 DL:110MiB ETA:54s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:13 2022 ***
# =
# [#9c9d46 1.9GiB/7.4GiB(26%) CN:3 DL:113MiB ETA:48s]
# FILE: /content/naifu.tar
# -
# [#8b1179 1.8GiB/7.1GiB(25%) CN:3 DL:108MiB ETA:50s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:19 2022 ***
# =
# [#9c9d46 2.5GiB/7.4GiB(34%) CN:3 DL:107MiB ETA:46s]
# FILE: /content/naifu.tar
# -
# [#8b1179 2.4GiB/7.1GiB(33%) CN:3 DL:98MiB ETA:49s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:25 2022 ***
# =
# [#9c9d46 3.1GiB/7.4GiB(42%) CN:3 DL:101MiB ETA:42s]
# FILE: /content/naifu.tar
# -
# [#8b1179 3.0GiB/7.1GiB(42%) CN:3 DL:99MiB ETA:42s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:31 2022 ***
# =
# [#9c9d46 3.8GiB/7.4GiB(51%) CN:3 DL:111MiB ETA:33s]
# FILE: /content/naifu.tar
# -
# [#8b1179 3.6GiB/7.1GiB(51%) CN:3 DL:106MiB ETA:33s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:37 2022 ***
# =
# [#9c9d46 4.4GiB/7.4GiB(60%) CN:3 DL:111MiB ETA:27s]
# FILE: /content/naifu.tar
# -
# [#8b1179 4.2GiB/7.1GiB(59%) CN:3 DL:106MiB ETA:28s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:43 2022 ***
# =
# [#9c9d46 5.0GiB/7.4GiB(67%) CN:3 DL:102MiB ETA:23s]
# FILE: /content/naifu.tar
# -
# [#8b1179 4.8GiB/7.1GiB(66%) CN:3 DL:96MiB ETA:25s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:49 2022 ***
# =
# [#9c9d46 5.6GiB/7.4GiB(76%) CN:3 DL:102MiB ETA:17s]
# FILE: /content/naifu.tar
# -
# [#8b1179 5.4GiB/7.1GiB(75%) CN:3 DL:95MiB ETA:18s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:49:55 2022 ***
# =
# [#9c9d46 6.2GiB/7.4GiB(84%) CN:3 DL:105MiB ETA:10s]
# FILE: /content/naifu.tar
# -
# [#8b1179 6.0GiB/7.1GiB(83%) CN:3 DL:106MiB ETA:11s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Thu Oct 27 14:50:01 2022 ***
# =
# [#9c9d46 6.9GiB/7.4GiB(93%) CN:3 DL:103MiB ETA:5s]
# FILE: /content/naifu.tar
# -
# [#8b1179 6.6GiB/7.1GiB(92%) CN:3 DL:105MiB ETA:5s]
# FILE: /content/animefull-latest.tar
# -
#
#
# 10/27 14:50:02 [ERROR] CUID#11 - Download aborted. URI=https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/animefull-latest.tar
# Exception: [AbstractCommand.cc:351] errorCode=22 URI=https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/animefull-latest.tar
#   -> [HttpSkipResponseCommand.cc:239] errorCode=22 The response status is not successful. status=500
#
# 10/27 14:50:04 [ERROR] CUID#7 - Download aborted. URI=https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/naifu.tar
# Exception: [AbstractCommand.cc:351] errorCode=22 URI=https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/naifu.tar
#   -> [HttpSkipResponseCommand.cc:239] errorCode=22 The response status is not successful. status=500
#
# 10/27 14:50:05 [ERROR] CUID#23 - Download aborted. URI=https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/naifu.tar
# Exception: [AbstractCommand.cc:351] errorCode=22 URI=https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/naifu.tar
#   -> [HttpSkipResponseCommand.cc:239] errorCode=22 The response status is not successful. status=500
#
# 10/27 14:50:05 [NOTICE] Download complete: /content/naifu.tar
#  *** Download Progress Summary as of Thu Oct 27 14:50:06 2022 ***
# =
# [#8b1179 7.0GiB/7.1GiB(98%) CN:2 DL:88MiB ETA:1s]
# FILE: /content/animefull-latest.tar
# -
#
#
# 10/27 14:50:08 [NOTICE] Download complete: /content/animefull-latest.tar
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9c9d46|OK  |   108MiB/s|/content/naifu.tar
# 8b1179|OK  |   100MiB/s|/content/animefull-latest.tar
#
# Status Legend:
# (OK):download completed.
# Decompressing...
# Done.

# %%
#@title ### 2. 安裝依賴
#@markdown 耐心等待安裝完成

# %cd /content/naifu
# !pip install virtualenv && bash ./setup.sh
# !curl -Ls https://github.com/ekzhang/bore/releases/download/v0.4.0/bore-v0.4.0-x86_64-unknown-linux-musl.tar.gz | tar zx -C /usr/bin
# !curl -Lo /usr/bin/cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 && chmod +x /usr/bin/cloudflared
# Out:
# /content/naifu
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting virtualenv
#   Downloading virtualenv-20.16.6-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 31.0 MB/s
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (3.8.0)
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (4.13.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 65.3 MB/s
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->virtualenv) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->virtualenv) (3.9.0)
# Installing collected packages: platformdirs, distlib, virtualenv
# Successfully installed distlib-0.3.6 platformdirs-2.5.2 virtualenv-20.16.6
# + virtualenv venv
# created virtual environment CPython3.7.15.final.0-64 in 764ms
#   creator CPython3Posix(dest=/content/naifu/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.3, setuptools==65.5.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# + . venv/bin/activate
# ++ '[' venv/bin/activate = ./setup.sh ']'
# ++ deactivate nondestructive
# ++ unset -f pydoc
# ++ '[' -z '' ']'
# ++ '[' -z '' ']'
# ++ hash -r
# ++ '[' -z '' ']'
# ++ unset VIRTUAL_ENV
# ++ '[' '!' nondestructive = nondestructive ']'
# ++ VIRTUAL_ENV=/content/naifu/venv
# ++ '[' linux-gnu = cygwin ']'
# ++ '[' linux-gnu = msys ']'
# ++ export VIRTUAL_ENV
# ++ _OLD_VIRTUAL_PATH=/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# ++ PATH=/content/naifu/venv/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# ++ export PATH
# ++ '[' -z '' ']'
# ++ '[' -z '' ']'
# ++ _OLD_VIRTUAL_PS1=
# ++ '[' x '!=' x ']'
# +++ basename /content/naifu/venv
# ++ PS1='(venv) '
# ++ export PS1
# ++ alias pydoc
# ++ true
# ++ hash -r
# + pip install -r requirements.txt
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu116
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu116/torch-1.13.0%2Bcu116-cp37-cp37m-linux_x86_64.whl (1983.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 2.0/2.0 GB 160.1 MB/s eta 0:00:01tcmalloc: large alloc 1983045632 bytes == 0x37dc000 @  0x7fa4be1081e7 0x4b2590 0x4b261c 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 2.0/2.0 GB 155.3 MB/s eta 0:00:01tcmalloc: large alloc 2478809088 bytes == 0x79b0a000 @  0x7fa4be109615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37
# tcmalloc: large alloc 1983045632 bytes == 0x37dc000 @  0x7fa4be1081e7 0x4b2590 0x5ad01c 0x5ad387 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x4bad99 0x4d3249 0x591e56 0x5fbace 0x590ae5 0x510946 0x58fd37 0x510325 0x5b4ee6 0x58ff2e 0x510325 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 869.0 kB/s eta 0:00:00
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu116/torchvision-0.14.0%2Bcu116-cp37-cp37m-linux_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 49.3 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu116/torchaudio-0.13.0%2Bcu116-cp37-cp37m-linux_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 62.0 MB/s eta 0:00:00
# Collecting dotmap
#   Downloading dotmap-1.3.30-py3-none-any.whl (11 kB)
# Collecting fastapi
#   Downloading fastapi-0.85.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 3.6 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.19.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 726.1 kB/s eta 0:00:00
# Collecting omegaconf
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 12.7 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 71.8 MB/s eta 0:00:00
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.8 MB/s eta 0:00:00

# %%
#@title ### 3. 啟動模型
#@markdown 訪問輸出的映射地址（以 `trycloudflare.com` / `bore.pub` 結尾）即可。
#@markdown - 請等待模型加載完成（出現`Application startup complete`字樣）再訪問
#@markdown - cloudflare 提供的服務偶爾會出現請求超時，可換用 bore 隧道

# %cd /content/naifu
# !sed -i 's/# export SAVE_FILES="1"/export SAVE_FILES="1"/g' run.sh
# !bash run.sh & cloudflared tunnel --url localhost:6969
# Out:
# /content/naifu
# 2022-10-27T01:57:55Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2022-10-27T01:57:55Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2022-10-27T01:57:55.384737Z  INFO bore_cli::client: connected to server remote_port=40271
# 2022-10-27T01:57:55.384777Z  INFO bore_cli::client: listening at bore.pub:40271
# 2022-10-27T01:57:58Z INF +--------------------------------------------------------------------------------------------+
# 2022-10-27T01:57:58Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2022-10-27T01:57:58Z INF |  https://ringtones-am-fares-implementing.trycloudflare.com                                 |
# 2022-10-27T01:57:58Z INF +--------------------------------------------------------------------------------------------+
# 2022-10-27T01:57:58Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2022-10-27T01:57:58Z INF Version 2022.10.3
# 2022-10-27T01:57:58Z INF GOOS: linux, GOVersion: go1.18.6, GoArch: amd64
# 2022-10-27T01:57:58Z INF Settings: map[protocol:quic url:localhost:6969]
# 2022-10-27T01:57:58Z INF Generated Connector ID: 091ab946-c9c6-49ce-9751-511f5a869c69
# 2022-10-27T01:57:58Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/run-tunnel/as-a-service/
# 2022-10-27T01:57:58Z INF Initial protocol quic
# 2022-10-27T01:57:58Z INF ICMP proxy will use 172.28.0.2 as source for IPv4
# 2022-10-27T01:57:58Z INF ICMP proxy will use :: as source for IPv6
# 2022-10-27T01:57:58Z WRN The user running cloudflared process has a GID (group ID) that is not within ping_group_range. You might need to add that user to a group within that range, or instead update the range to encompass a group the user is already in by modifying /proc/sys/net/ipv4/ping_group_range. Otherwise cloudflared will not be able to ping this network error="Group ID 0 is not between ping group 1 to 0"
# 2022-10-27T01:57:58Z WRN ICMP proxy feature is disabled error="cannot create ICMPv4 proxy: Group ID 0 is not between ping group 1 to 0 nor ICMPv6 proxy: socket: permission denied"
# 2022-10-27T01:57:58Z INF Starting metrics server on 127.0.0.1:43467/metrics
# 2022/10/27 01:57:58 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 2048 kiB, got: 416 kiB). See https://github.com/lucas-clemente/quic-go/wiki/UDP-Receive-Buffer-Size for details.
# 2022-10-27T01:57:58Z ERR Failed to serve quic connection error="Unauthorized: Failed to get tunnel" connIndex=0 ip=198.41.200.113
# 2022-10-27T01:57:58Z ERR Register tunnel error from server side error="Unauthorized: Failed to get tunnel" connIndex=0 ip=198.41.200.113
# Starting Hydra Node HTTP TOKEN=None
# 2022-10-27 01:57:58,367 INFO config.py(679) - CPU: Intel(R) Xeon(R) CPU @ 2.00GHz
# 2022-10-27 01:57:58,367 INFO config.py(679) - GPU: Tesla T4
# 2022-10-27 01:57:58,367 INFO config.py(679) - GPU RAM: 15gb
# 2022-10-27 01:57:58,367 INFO config.py(679) - MODEL: stable-diffusion
# 2022-10-27 01:57:58,367 INFO models.py(679) - Loading model from folder models/animefull-final-pruned
# Loading model from models/animefull-final-pruned/model.ckpt
# 2022-10-27T01:57:58Z INF Retrying connection in up to 2s connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:00Z ERR Failed to serve quic connection error="Unauthorized: Failed to get tunnel" connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:00Z ERR Register tunnel error from server side error="Unauthorized: Failed to get tunnel" connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:00Z INF Retrying connection in up to 4s connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:02Z ERR Failed to serve quic connection error="Unauthorized: Failed to get tunnel" connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:02Z ERR Register tunnel error from server side error="Unauthorized: Failed to get tunnel" connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:02Z INF Retrying connection in up to 8s connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:03Z ERR Failed to serve quic connection error="Unauthorized: Failed to get tunnel" connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:03Z ERR Register tunnel error from server side error="Unauthorized: Failed to get tunnel" connIndex=0 ip=198.41.200.113
# 2022-10-27T01:58:03Z INF Retrying connection in up to 16s connIndex=0 ip=198.41.200.113
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 64, 64) = 16384 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Started frozen clip class
# 2022-10-27T01:58:13Z INF Connection f7b2a55d-a7db-45d7-88c5-110fdb6d653d registered connIndex=0 ip=198.41.200.113 location=SIN
# 2022-10-27T01:58:14Z INF Connection 0c0437dc-9952-48aa-bedd-334d83e707ae registered connIndex=1 ip=198.41.192.7 location=HKG
# 2022-10-27T01:58:15Z INF Connection 59eae0e9-5899-4b63-8562-b2fc94c4a2a3 registered connIndex=2 ip=198.41.200.23 location=SIN
# 2022-10-27T01:58:16Z INF Connection 6c4dc277-feee-4c71-8764-303b5d0cc284 registered connIndex=3 ip=198.41.192.27 location=HKG
# 2022-10-27 01:58:31,341 INFO models.py(679) - Using VAE from models/animevae.pt
# 2022-10-27 01:58:31,341 INFO models.py(679) - CLIP: Using penultimate layer
# 2022-10-27 01:58:31,369 INFO models.py(679) - Using EMA
# 2022-10-27 01:58:50,587 INFO config.py(679) - Models loaded in 52.22s
# Loaded tag suggestion model using phrase embeddings
# INFO:     Started server process [679]
# INFO:     Waiting for application startup.
# 2022-10-27 01:58:53,099 INFO main.py(679) - FastAPI Started, serving
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:6969 (Press CTRL+C to quit)
# INFO:     45.94.42.246:0 - "GET / HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/pages/_app-128a4b077453e8e5.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/css/32f1e54debdb3c74.css HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/MG2vPPHR3En34h0ZDGvU7/_buildManifest.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/webpack-b9b5e27f3c90f79a.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/main-f17b067b102428ca.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/MG2vPPHR3En34h0ZDGvU7/_ssgManifest.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/pages/index-67838cc9a284731b.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/import.a2828e2c.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/cross.fac5a02a.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/pen.87137c5d.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/SourceSansPro-Regular.ba487c32.woff2 HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/check.c906eb0a.svg HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET / HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET / HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET / HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET / HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/chunks/webpack-b9b5e27f3c90f79a.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/css/32f1e54debdb3c74.css HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/chunks/webpack-b9b5e27f3c90f79a.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/css/32f1e54debdb3c74.css HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/chunks/pages/index-67838cc9a284731b.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/chunks/main-f17b067b102428ca.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/MG2vPPHR3En34h0ZDGvU7/_buildManifest.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/chunks/pages/_app-128a4b077453e8e5.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/media/history.b9b000e8.svg HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/media/SourceSansPro-Regular.ba487c32.woff2 HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/MG2vPPHR3En34h0ZDGvU7/_ssgManifest.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/media/cross.fac5a02a.svg HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/media/check.c906eb0a.svg HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/chunks/main-f17b067b102428ca.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/MG2vPPHR3En34h0ZDGvU7/_buildManifest.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/chunks/pages/_app-128a4b077453e8e5.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/MG2vPPHR3En34h0ZDGvU7/_ssgManifest.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/media/history.b9b000e8.svg HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/chunks/pages/index-67838cc9a284731b.js HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/media/SourceSansPro-Regular.ba487c32.woff2 HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /_next/static/media/cross.fac5a02a.svg HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /icons/novelai-round.png HTTP/1.1" 200 OK
# INFO:     34.83.203.92:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     45.94.42.246:0 - "GET /icons/novelai-round.png HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /manifest.json HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /icons/novelai512.png HTTP/1.1" 404 Not Found
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/247.9ec9f56bc609a550.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/140.a9739eb472fc0dc3.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /tokenizer/clip_tokenizer.json?static=true HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/157.4184b7ea2aeb8d93.js HTTP/1.1" 200 OK
# 2022-10-27T02:02:02.203597Z  INFO proxy{id=058d0851-bad0-4da0-a958-d3aea4909e59}: bore_cli::client: new connection
# 2022-10-27T02:02:02.651422Z  INFO proxy{id=058d0851-bad0-4da0-a958-d3aea4909e59}: bore_cli::client: connection exited
# 2022-10-27 02:17:53,243 INFO main.py(679) - Request took 3.275 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=c%27y%27be HTTP/1.1" 200 OK
# 2022-10-27 02:17:53,273 INFO main.py(679) - Request took 0.025 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=cyber HTTP/1.1" 200 OK
# 100% 28/28 [00:14<00:00,  1.96it/s]
# 2022-10-27 02:18:15,946 INFO main.py(679) - Request took 18.200 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/clipboard.579cb9e6.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/variations.d35c8a3a.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/sparkles.b1e1a420.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/save.36b86afc.svg HTTP/1.1" 200 OK
# 2022-10-27 02:18:28,953 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=1girl HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.41it/s]
# 2022-10-27 02:18:43,765 INFO main.py(679) - Request took 14.562 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.33it/s]
# 2022-10-27 02:19:10,340 INFO main.py(679) - Request took 14.765 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 02:19:33,939 INFO main.py(679) - Request took 0.029 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=1girl HTTP/1.1" 200 OK
# 2022-10-27 02:19:35,960 INFO main.py(679) - Request took 0.026 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=cute HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.39it/s]
# 2022-10-27 02:19:50,454 INFO main.py(679) - Request took 14.478 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 02:20:42,379 INFO main.py(679) - Request took 0.028 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Floating%20long%20hair HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.35it/s]
# 2022-10-27 02:20:57,143 INFO main.py(679) - Request took 14.664 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 02:21:14,326 INFO main.py(679) - Request took 0.028 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Floating%20long%20hair%EF%BC%8C HTTP/1.1" 200 OK
# 2022-10-27 02:21:28,243 INFO main.py(679) - Request took 0.026 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Floating HTTP/1.1" 200 OK
# 2022-10-27 02:21:51,476 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Floating%20hair HTTP/1.1" 200 OK
# 2022-10-27 02:21:52,935 INFO main.py(679) - Request took 0.031 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=colored%20hair HTTP/1.1" 200 OK
# 2022-10-27 02:21:57,226 INFO main.py(679) - Request took 0.033 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Floating%20hair HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.36it/s]
# 2022-10-27 02:22:13,971 INFO main.py(679) - Request took 14.677 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 02:22:35,899 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=sm HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.35it/s]
# 2022-10-27 02:22:55,989 INFO main.py(679) - Request took 14.622 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.36it/s]
# 2022-10-27 02:24:39,664 INFO main.py(679) - Request took 14.615 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 02:25:04,279 INFO main.py(679) - Request took 0.035 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=cute HTTP/1.1" 200 OK
# 2022-10-27 02:25:06,693 INFO main.py(679) - Request took 0.026 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=young HTTP/1.1" 200 OK
#   0% 0/28 [00:00<?, ?it/s]2022-10-27 02:25:07,647 INFO main.py(679) - Request took 0.269 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=young%27 HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.35it/s]
# 2022-10-27 02:25:21,534 INFO main.py(679) - Request took 14.677 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.38it/s]
# 2022-10-27 02:26:16,541 INFO main.py(679) - Request took 14.503 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.37it/s]
# 100% 28/28 [00:11<00:00,  2.51it/s]
# 100% 28/28 [00:11<00:00,  2.53it/s]
# 2022-10-27 02:27:22,148 INFO main.py(679) - Request took 39.238 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 02:29:01,839 INFO main.py(679) - Request took 0.030 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=young%EF%BC%8C HTTP/1.1" 200 OK
# 2022-10-27 02:29:02,444 INFO main.py(679) - Request took 0.026 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=young HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.45it/s]
# 100% 28/28 [00:10<00:00,  2.65it/s]
# 100% 28/28 [00:10<00:00,  2.56it/s]
# 2022-10-27 02:29:44,290 INFO main.py(679) - Request took 38.196 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.42it/s]
# 100% 28/28 [00:10<00:00,  2.61it/s]
# 100% 28/28 [00:11<00:00,  2.51it/s]
# 2022-10-27 02:31:53,403 INFO main.py(679) - Request took 38.811 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 02:34:09,896 INFO main.py(679) - Request took 0.030 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=colored_hair HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.43it/s]
# 100% 28/28 [00:10<00:00,  2.62it/s]
# 100% 28/28 [00:11<00:00,  2.53it/s]
# 2022-10-27 02:34:49,920 INFO main.py(679) - Request took 38.607 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 41/41 [00:15<00:00,  2.68it/s]
# 100% 41/41 [00:14<00:00,  2.86it/s]
# 100% 41/41 [00:14<00:00,  2.82it/s]
# 2022-10-27 03:04:42,082 INFO main.py(679) - Request took 49.555 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 41/41 [00:15<00:00,  2.73it/s]
# 100% 41/41 [00:13<00:00,  2.94it/s]
# 100% 41/41 [00:14<00:00,  2.93it/s]
# 2022-10-27 03:09:03,573 INFO main.py(679) - Request took 48.112 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 41/41 [00:14<00:00,  2.76it/s]
# 100% 41/41 [00:13<00:00,  2.95it/s]
# 100% 41/41 [00:13<00:00,  2.94it/s]
# 2022-10-27 03:14:18,545 INFO main.py(679) - Request took 47.813 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 03:21:13,741 INFO main.py(679) - Request took 0.031 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=sexy HTTP/1.1" 200 OK
# 100% 28/28 [00:10<00:00,  2.67it/s]
# 100% 28/28 [00:09<00:00,  2.99it/s]
# 100% 28/28 [00:09<00:00,  2.97it/s]
# 2022-10-27 03:21:47,886 INFO main.py(679) - Request took 34.142 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 41/41 [00:14<00:00,  2.77it/s]
# 100% 41/41 [00:13<00:00,  2.96it/s]
# 100% 41/41 [00:13<00:00,  2.95it/s]
# 2022-10-27 03:59:34,770 INFO main.py(679) - Request took 47.666 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 41/41 [00:16<00:00,  2.48it/s]
# 100% 41/41 [00:16<00:00,  2.52it/s]
# 100% 41/41 [00:15<00:00,  2.56it/s]
# 2022-10-27 04:42:10,866 INFO main.py(679) - Request took 54.117 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/select.429034b7.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/penwriting.3c214126.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/dropper.78b85b64.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/eraser.0ec62cc8.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/undo.d181fecf.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/redo.c8b50748.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/small_cross.8d803d20.svg HTTP/1.1" 200 OK
# 100% 36/36 [00:14<00:00,  2.53it/s]
# 100% 36/36 [00:13<00:00,  2.61it/s]
# 100% 36/36 [00:14<00:00,  2.52it/s]
# 2022-10-27 04:43:45,175 INFO main.py(679) - Request took 47.708 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 36/36 [00:14<00:00,  2.52it/s]
# 100% 36/36 [00:13<00:00,  2.59it/s]
# 100% 36/36 [00:14<00:00,  2.52it/s]
# 2022-10-27 04:45:30,031 INFO main.py(679) - Request took 47.750 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET / HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/main-f17b067b102428ca.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/css/32f1e54debdb3c74.css HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/webpack-b9b5e27f3c90f79a.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/pages/_app-128a4b077453e8e5.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/MG2vPPHR3En34h0ZDGvU7/_buildManifest.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/MG2vPPHR3En34h0ZDGvU7/_ssgManifest.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/pages/index-67838cc9a284731b.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/cross.fac5a02a.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/import.a2828e2c.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/check.c906eb0a.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/pen.87137c5d.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/SourceSansPro-Regular.ba487c32.woff2 HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /icons/novelai-round.png HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /manifest.json HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /icons/novelai512.png HTTP/1.1" 404 Not Found
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/247.9ec9f56bc609a550.js HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/chunks/140.a9739eb472fc0dc3.js HTTP/1.1" 200 OK
# 2022-10-27 04:49:29,824 INFO main.py(679) - Request took 0.032 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=month HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /tokenizer/clip_tokenizer.json?static=true HTTP/1.1" 200 OK
# 2022-10-27 04:49:33,349 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=month%EF%BC%8C HTTP/1.1" 200 OK
# 2022-10-27 04:49:34,644 INFO main.py(679) - Request took 0.031 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=month%EF%BC%8Cc%27y HTTP/1.1" 200 OK
# 2022-10-27 04:49:36,736 INFO main.py(679) - Request took 0.028 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=month%EF%BC%8Cc%27y HTTP/1.1" 200 OK
# 2022-10-27 04:49:36,821 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=month%EF%BC%8Ccyber HTTP/1.1" 200 OK
# 2022-10-27 04:49:43,906 INFO main.py(679) - Request took 0.028 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=mo HTTP/1.1" 200 OK
# 2022-10-27 04:49:46,324 INFO main.py(679) - Request took 0.026 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=month HTTP/1.1" 200 OK
# 2022-10-27 04:49:48,943 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=mo HTTP/1.1" 200 OK
# 2022-10-27 04:49:49,900 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=moon HTTP/1.1" 200 OK
#  57% 16/28 [00:06<00:04,  2.70it/s]INFO:     45.94.42.246:0 - "GET /_next/static/chunks/157.4184b7ea2aeb8d93.js HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.46it/s]
# 2022-10-27 04:50:06,188 INFO main.py(679) - Request took 14.127 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/clipboard.579cb9e6.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/sparkles.b1e1a420.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/variations.d35c8a3a.svg HTTP/1.1" 200 OK
# INFO:     45.94.42.246:0 - "GET /_next/static/media/save.36b86afc.svg HTTP/1.1" 200 OK
# 2022-10-27 04:50:43,772 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=girl HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.41it/s]
# 2022-10-27 04:51:10,191 INFO main.py(679) - Request took 14.350 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 04:54:48,171 INFO main.py(679) - Request took 0.101 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Girl%20with%20long%20hair HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.47it/s]
# 2022-10-27 04:55:02,125 INFO main.py(679) - Request took 14.066 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 04:56:11,739 INFO main.py(679) - Request took 0.029 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Girl%20with%20long%20hair%EF%BC%8C HTTP/1.1" 200 OK
# 2022-10-27 04:56:16,002 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Girl%20with%20long%20hair%EF%BC%8C HTTP/1.1" 200 OK
# 2022-10-27 04:56:31,842 INFO main.py(679) - Request took 0.026 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=Girl HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.47it/s]
# 2022-10-27 04:56:47,511 INFO main.py(679) - Request took 14.074 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.44it/s]
# 2022-10-27 04:57:53,472 INFO main.py(679) - Request took 14.186 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 04:58:32,411 INFO main.py(679) - Request took 0.029 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=by%20Dora%20Maar HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.42it/s]
# 2022-10-27 04:58:47,905 INFO main.py(679) - Request took 14.268 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.38it/s]
# 100% 28/28 [00:10<00:00,  2.56it/s]
# 100% 28/28 [00:11<00:00,  2.52it/s]
# 100% 28/28 [00:10<00:00,  2.60it/s]
# 100% 28/28 [00:10<00:00,  2.65it/s]
#  32% 9/28 [00:03<00:07,  2.63it/s]2022-10-27T05:00:26Z ERR  error="Incoming request ended abruptly: context canceled" cfRay=7608dcc2e5ca2410-HKG originService=http://localhost:6969
# 2022-10-27T05:00:26Z ERR Request failed error="Incoming request ended abruptly: context canceled" connIndex=3 dest=https://ringtones-am-fares-implementing.trycloudflare.com/generate-stream ip=198.41.192.27 type=http
# 100% 28/28 [00:10<00:00,  2.69it/s]
#   4% 1/28 [00:01<00:36,  1.36s/it]2022-10-27 05:00:41,533 INFO main.py(679) - Request took 74.938 seconds
# 100% 28/28 [00:11<00:00,  2.43it/s]
# 100% 28/28 [00:10<00:00,  2.66it/s]
# 100% 28/28 [00:10<00:00,  2.62it/s]
# 100% 28/28 [00:10<00:00,  2.61it/s]
#  18% 5/28 [00:01<00:08,  2.72it/s]2022-10-27T05:01:26Z ERR  error="Incoming request ended abruptly: context canceled" cfRay=7608de3de1d104ee-HKG originService=http://localhost:6969
# 2022-10-27T05:01:26Z ERR Request failed error="Incoming request ended abruptly: context canceled" connIndex=2 dest=https://ringtones-am-fares-implementing.trycloudflare.com/generate-stream ip=198.41.200.23 type=http
# 100% 28/28 [00:10<00:00,  2.63it/s]
# 100% 28/28 [00:10<00:00,  2.65it/s]
#   4% 1/28 [00:01<00:36,  1.36s/it]2022-10-27 05:01:53,859 INFO main.py(679) - Request took 86.532 seconds
# 100% 28/28 [00:11<00:00,  2.40it/s]
# 2022-10-27 05:02:06,385 INFO main.py(679) - Request took 21.703 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 05:02:38,446 INFO main.py(679) - Request took 0.028 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=1irl HTTP/1.1" 200 OK
# 2022-10-27 05:02:40,935 INFO main.py(679) - Request took 0.026 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=1g HTTP/1.1" 200 OK
# 2022-10-27 05:02:42,701 INFO main.py(679) - Request took 0.027 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=1girl HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.48it/s]
# 2022-10-27 05:03:06,353 INFO main.py(679) - Request took 13.951 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 2022-10-27 05:03:49,384 INFO main.py(679) - Request took 0.029 seconds
# INFO:     45.94.42.246:0 - "GET /predict-tags?prompt=by%20Dora%20Maar HTTP/1.1" 200 OK
# 100% 28/28 [00:11<00:00,  2.44it/s]
# 2022-10-27 05:04:03,663 INFO main.py(679) - Request took 14.180 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 41/41 [00:16<00:00,  2.45it/s]
# 100% 41/41 [00:16<00:00,  2.52it/s]
# 100% 41/41 [00:15<00:00,  2.59it/s]
# 2022-10-27 05:05:19,947 INFO main.py(679) - Request took 54.090 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK
# 100% 41/41 [00:15<00:00,  2.57it/s]
# 100% 41/41 [00:15<00:00,  2.63it/s]
# 100% 41/41 [00:16<00:00,  2.53it/s]
# 2022-10-27 05:06:51,681 INFO main.py(679) - Request took 53.102 seconds
# INFO:     45.94.42.246:0 - "POST /generate-stream HTTP/1.1" 200 OK

# %%
#@title ### 4. （可選）使用 7G 的 `animefull-latest` 模型運行
#@markdown 默認使用的是 4G 大小的 animefull-final-pruned 模型。如果想使用 7G 的 animefull-latest 模型，運行這個

# %cd /content/
# !tar xf animefull-latest.tar -C /content/naifu/models && rm animefull-latest.tar
# !sed -i 's/map_location="cpu"/map_location="cuda"/g' /content/naifu/hydra_node/models.py

# %cd /content/naifu
# %env DTYPE=float16
# %env CLIP_CONTEXTS=3
# %env AMP=1
# %env MODEL=stable-diffusion
# %env DEV=True
# %env MODEL_PATH=models/animefull-latest
# %env ENABLE_EMA=1
# %env VAE_PATH=models/animevae.pt
# %env PENULTIMATE=1
# %env PYTHONDONTWRITEBYTECODE=1
# %env SAVE_FILES=1

# !./venv/bin/python -m uvicorn --host 0.0.0.0 --port=6969 main:app & bore local 6969 --to bore.pub & cloudflared tunnel --url localhost:6969
